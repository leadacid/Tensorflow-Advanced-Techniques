# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 982us/sample - loss: 258.1712 - y1_output_loss: 122.6553 - y2_output_loss: 133.0822 - y1_output_root_mean_squared_error: 11.1276 - y2_output_root_mean_squared_error: 11.5908 - val_loss: 26.9501 - val_y1_output_loss: 14.4651 - val_y2_output_loss: 13.0939 - val_y1_output_root_mean_squared_error: 3.7176 - val_y2_output_root_mean_squared_error: 3.6235
# Epoch 2/500
# 614/614 [==============================] - 0s 160us/sample - loss: 28.0373 - y1_output_loss: 11.4144 - y2_output_loss: 16.3963 - y1_output_root_mean_squared_error: 3.3942 - y2_output_root_mean_squared_error: 4.0641 - val_loss: 29.9942 - val_y1_output_loss: 12.0712 - val_y2_output_loss: 18.3980 - val_y1_output_root_mean_squared_error: 3.4258 - val_y2_output_root_mean_squared_error: 4.2729
# Epoch 3/500
# 614/614 [==============================] - 0s 148us/sample - loss: 29.7641 - y1_output_loss: 11.2175 - y2_output_loss: 18.3671 - y1_output_root_mean_squared_error: 3.3605 - y2_output_root_mean_squared_error: 4.2978 - val_loss: 25.9209 - val_y1_output_loss: 9.7294 - val_y2_output_loss: 16.4491 - val_y1_output_root_mean_squared_error: 3.0834 - val_y2_output_root_mean_squared_error: 4.0514
# Epoch 4/500
# 614/614 [==============================] - 0s 144us/sample - loss: 23.2389 - y1_output_loss: 9.3327 - y2_output_loss: 14.0987 - y1_output_root_mean_squared_error: 3.0385 - y2_output_root_mean_squared_error: 3.7425 - val_loss: 21.4224 - val_y1_output_loss: 10.8243 - val_y2_output_loss: 10.4131 - val_y1_output_root_mean_squared_error: 3.2825 - val_y2_output_root_mean_squared_error: 3.2631
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 28.3190 - y1_output_loss: 9.9244 - y2_output_loss: 18.5272 - y1_output_root_mean_squared_error: 3.1459 - y2_output_root_mean_squared_error: 4.2921 - val_loss: 63.7279 - val_y1_output_loss: 17.6266 - val_y2_output_loss: 47.0159 - val_y1_output_root_mean_squared_error: 4.1419 - val_y2_output_root_mean_squared_error: 6.8244
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.4157 - y1_output_loss: 9.1048 - y2_output_loss: 15.2662 - y1_output_root_mean_squared_error: 3.0176 - y2_output_root_mean_squared_error: 3.9128 - val_loss: 28.6503 - val_y1_output_loss: 12.0210 - val_y2_output_loss: 17.0327 - val_y1_output_root_mean_squared_error: 3.4088 - val_y2_output_root_mean_squared_error: 4.1268
# Epoch 7/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.5569 - y1_output_loss: 9.0631 - y2_output_loss: 14.8094 - y1_output_root_mean_squared_error: 3.0013 - y2_output_root_mean_squared_error: 3.8143 - val_loss: 25.3829 - val_y1_output_loss: 9.7038 - val_y2_output_loss: 15.7677 - val_y1_output_root_mean_squared_error: 3.0899 - val_y2_output_root_mean_squared_error: 3.9794
# Epoch 8/500
# 614/614 [==============================] - 0s 149us/sample - loss: 25.4974 - y1_output_loss: 8.8415 - y2_output_loss: 16.5831 - y1_output_root_mean_squared_error: 2.9842 - y2_output_root_mean_squared_error: 4.0733 - val_loss: 22.4647 - val_y1_output_loss: 9.5681 - val_y2_output_loss: 12.8168 - val_y1_output_root_mean_squared_error: 3.0746 - val_y2_output_root_mean_squared_error: 3.6071
# Epoch 9/500
# 614/614 [==============================] - 0s 147us/sample - loss: 21.0938 - y1_output_loss: 7.9634 - y2_output_loss: 13.0259 - y1_output_root_mean_squared_error: 2.8212 - y2_output_root_mean_squared_error: 3.6242 - val_loss: 23.6933 - val_y1_output_loss: 10.4174 - val_y2_output_loss: 12.9648 - val_y1_output_root_mean_squared_error: 3.2379 - val_y2_output_root_mean_squared_error: 3.6345
# Epoch 10/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.6990 - y1_output_loss: 7.7872 - y2_output_loss: 11.9051 - y1_output_root_mean_squared_error: 2.7882 - y2_output_root_mean_squared_error: 3.4533 - val_loss: 21.7062 - val_y1_output_loss: 9.5760 - val_y2_output_loss: 11.8032 - val_y1_output_root_mean_squared_error: 3.0989 - val_y2_output_root_mean_squared_error: 3.4789
# Epoch 11/500
# 614/614 [==============================] - 0s 177us/sample - loss: 20.8770 - y1_output_loss: 7.9869 - y2_output_loss: 12.7994 - y1_output_root_mean_squared_error: 2.8242 - y2_output_root_mean_squared_error: 3.5918 - val_loss: 17.2992 - val_y1_output_loss: 7.8346 - val_y2_output_loss: 9.2782 - val_y1_output_root_mean_squared_error: 2.7878 - val_y2_output_root_mean_squared_error: 3.0866
# Epoch 12/500
# 614/614 [==============================] - 0s 145us/sample - loss: 21.3553 - y1_output_loss: 7.7104 - y2_output_loss: 14.0257 - y1_output_root_mean_squared_error: 2.7199 - y2_output_root_mean_squared_error: 3.7360 - val_loss: 34.0847 - val_y1_output_loss: 11.6276 - val_y2_output_loss: 23.1837 - val_y1_output_root_mean_squared_error: 3.3456 - val_y2_output_root_mean_squared_error: 4.7845
# Epoch 13/500
# 614/614 [==============================] - 0s 146us/sample - loss: 18.6494 - y1_output_loss: 7.0596 - y2_output_loss: 11.4812 - y1_output_root_mean_squared_error: 2.6687 - y2_output_root_mean_squared_error: 3.3952 - val_loss: 22.1165 - val_y1_output_loss: 7.4023 - val_y2_output_loss: 14.4773 - val_y1_output_root_mean_squared_error: 2.7281 - val_y2_output_root_mean_squared_error: 3.8307
# Epoch 14/500
# 614/614 [==============================] - 0s 150us/sample - loss: 15.4272 - y1_output_loss: 6.1720 - y2_output_loss: 9.2467 - y1_output_root_mean_squared_error: 2.4928 - y2_output_root_mean_squared_error: 3.0353 - val_loss: 18.8450 - val_y1_output_loss: 6.4232 - val_y2_output_loss: 12.2999 - val_y1_output_root_mean_squared_error: 2.5270 - val_y2_output_root_mean_squared_error: 3.5298
# Epoch 15/500
# 614/614 [==============================] - 0s 171us/sample - loss: 18.7927 - y1_output_loss: 6.9478 - y2_output_loss: 11.7503 - y1_output_root_mean_squared_error: 2.6380 - y2_output_root_mean_squared_error: 3.4400 - val_loss: 13.7559 - val_y1_output_loss: 6.2977 - val_y2_output_loss: 7.2330 - val_y1_output_root_mean_squared_error: 2.4999 - val_y2_output_root_mean_squared_error: 2.7397
# Epoch 16/500
# 614/614 [==============================] - 0s 150us/sample - loss: 18.4136 - y1_output_loss: 6.3942 - y2_output_loss: 12.0980 - y1_output_root_mean_squared_error: 2.5339 - y2_output_root_mean_squared_error: 3.4631 - val_loss: 54.4762 - val_y1_output_loss: 10.0185 - val_y2_output_loss: 45.1959 - val_y1_output_root_mean_squared_error: 3.1667 - val_y2_output_root_mean_squared_error: 6.6669
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 16.0942 - y1_output_loss: 6.1350 - y2_output_loss: 10.0691 - y1_output_root_mean_squared_error: 2.4635 - y2_output_root_mean_squared_error: 3.1663 - val_loss: 37.1525 - val_y1_output_loss: 12.5380 - val_y2_output_loss: 25.3162 - val_y1_output_root_mean_squared_error: 3.4793 - val_y2_output_root_mean_squared_error: 5.0047
# Epoch 18/500
# 614/614 [==============================] - 0s 157us/sample - loss: 16.8877 - y1_output_loss: 6.3159 - y2_output_loss: 10.6816 - y1_output_root_mean_squared_error: 2.5129 - y2_output_root_mean_squared_error: 3.2516 - val_loss: 34.0018 - val_y1_output_loss: 8.3537 - val_y2_output_loss: 25.8224 - val_y1_output_root_mean_squared_error: 2.9049 - val_y2_output_root_mean_squared_error: 5.0560
# Epoch 19/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.6557 - y1_output_loss: 5.6572 - y2_output_loss: 8.1475 - y1_output_root_mean_squared_error: 2.3536 - y2_output_root_mean_squared_error: 2.8489 - val_loss: 12.0468 - val_y1_output_loss: 5.3722 - val_y2_output_loss: 6.5454 - val_y1_output_root_mean_squared_error: 2.2937 - val_y2_output_root_mean_squared_error: 2.6050
# Epoch 20/500
# 614/614 [==============================] - 0s 145us/sample - loss: 15.5709 - y1_output_loss: 5.5679 - y2_output_loss: 10.1087 - y1_output_root_mean_squared_error: 2.3469 - y2_output_root_mean_squared_error: 3.1722 - val_loss: 13.8619 - val_y1_output_loss: 5.9895 - val_y2_output_loss: 7.6913 - val_y1_output_root_mean_squared_error: 2.4407 - val_y2_output_root_mean_squared_error: 2.8115
# Epoch 21/500
# 614/614 [==============================] - 0s 154us/sample - loss: 13.7074 - y1_output_loss: 5.1505 - y2_output_loss: 8.5382 - y1_output_root_mean_squared_error: 2.2730 - y2_output_root_mean_squared_error: 2.9224 - val_loss: 12.3127 - val_y1_output_loss: 4.9271 - val_y2_output_loss: 7.2151 - val_y1_output_root_mean_squared_error: 2.2153 - val_y2_output_root_mean_squared_error: 2.7213
# Epoch 22/500
# 614/614 [==============================] - 0s 143us/sample - loss: 13.8157 - y1_output_loss: 5.0189 - y2_output_loss: 8.8277 - y1_output_root_mean_squared_error: 2.2459 - y2_output_root_mean_squared_error: 2.9617 - val_loss: 17.3712 - val_y1_output_loss: 5.2706 - val_y2_output_loss: 12.2705 - val_y1_output_root_mean_squared_error: 2.2842 - val_y2_output_root_mean_squared_error: 3.4862
# Epoch 23/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.1136 - y1_output_loss: 4.7679 - y2_output_loss: 7.3304 - y1_output_root_mean_squared_error: 2.1936 - y2_output_root_mean_squared_error: 2.7022 - val_loss: 38.0687 - val_y1_output_loss: 7.5539 - val_y2_output_loss: 31.0284 - val_y1_output_root_mean_squared_error: 2.7591 - val_y2_output_root_mean_squared_error: 5.5187
# Epoch 24/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.6048 - y1_output_loss: 4.7900 - y2_output_loss: 7.8992 - y1_output_root_mean_squared_error: 2.1666 - y2_output_root_mean_squared_error: 2.8126 - val_loss: 26.5066 - val_y1_output_loss: 9.2487 - val_y2_output_loss: 17.6639 - val_y1_output_root_mean_squared_error: 2.9890 - val_y2_output_root_mean_squared_error: 4.1919
# Epoch 25/500
# 614/614 [==============================] - 0s 149us/sample - loss: 13.3023 - y1_output_loss: 4.3782 - y2_output_loss: 8.8876 - y1_output_root_mean_squared_error: 2.1020 - y2_output_root_mean_squared_error: 2.9806 - val_loss: 16.9319 - val_y1_output_loss: 5.3825 - val_y2_output_loss: 11.4072 - val_y1_output_root_mean_squared_error: 2.3488 - val_y2_output_root_mean_squared_error: 3.3786
# Epoch 26/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.5813 - y1_output_loss: 4.3374 - y2_output_loss: 7.2060 - y1_output_root_mean_squared_error: 2.0836 - y2_output_root_mean_squared_error: 2.6907 - val_loss: 20.6287 - val_y1_output_loss: 6.3713 - val_y2_output_loss: 14.3068 - val_y1_output_root_mean_squared_error: 2.5002 - val_y2_output_root_mean_squared_error: 3.7918
# Epoch 27/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.1589 - y1_output_loss: 3.9788 - y2_output_loss: 7.1300 - y1_output_root_mean_squared_error: 1.9954 - y2_output_root_mean_squared_error: 2.6791 - val_loss: 12.1042 - val_y1_output_loss: 4.0207 - val_y2_output_loss: 7.9965 - val_y1_output_root_mean_squared_error: 2.0135 - val_y2_output_root_mean_squared_error: 2.8372
# Epoch 28/500
# 614/614 [==============================] - 0s 155us/sample - loss: 12.5222 - y1_output_loss: 4.1822 - y2_output_loss: 8.2466 - y1_output_root_mean_squared_error: 2.0516 - y2_output_root_mean_squared_error: 2.8832 - val_loss: 9.6055 - val_y1_output_loss: 3.7990 - val_y2_output_loss: 5.6312 - val_y1_output_root_mean_squared_error: 1.9553 - val_y2_output_root_mean_squared_error: 2.4047
# Epoch 29/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.1787 - y1_output_loss: 3.6081 - y2_output_loss: 6.5360 - y1_output_root_mean_squared_error: 1.9064 - y2_output_root_mean_squared_error: 2.5582 - val_loss: 10.0058 - val_y1_output_loss: 3.6454 - val_y2_output_loss: 6.3027 - val_y1_output_root_mean_squared_error: 1.8979 - val_y2_output_root_mean_squared_error: 2.5305
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.0258 - y1_output_loss: 3.7248 - y2_output_loss: 6.5760 - y1_output_root_mean_squared_error: 1.9325 - y2_output_root_mean_squared_error: 2.5082 - val_loss: 38.9110 - val_y1_output_loss: 6.9660 - val_y2_output_loss: 32.7480 - val_y1_output_root_mean_squared_error: 2.6517 - val_y2_output_root_mean_squared_error: 5.6462
# Epoch 31/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.8517 - y1_output_loss: 3.5522 - y2_output_loss: 6.2741 - y1_output_root_mean_squared_error: 1.8871 - y2_output_root_mean_squared_error: 2.5081 - val_loss: 8.7726 - val_y1_output_loss: 3.4135 - val_y2_output_loss: 5.1946 - val_y1_output_root_mean_squared_error: 1.8561 - val_y2_output_root_mean_squared_error: 2.3082
# Epoch 32/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.1791 - y1_output_loss: 3.6467 - y2_output_loss: 6.4579 - y1_output_root_mean_squared_error: 1.9180 - y2_output_root_mean_squared_error: 2.5495 - val_loss: 14.9720 - val_y1_output_loss: 4.1058 - val_y2_output_loss: 11.0968 - val_y1_output_root_mean_squared_error: 2.0290 - val_y2_output_root_mean_squared_error: 3.2947
# Epoch 33/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.0398 - y1_output_loss: 3.2424 - y2_output_loss: 5.8041 - y1_output_root_mean_squared_error: 1.8071 - y2_output_root_mean_squared_error: 2.4030 - val_loss: 11.5351 - val_y1_output_loss: 2.8423 - val_y2_output_loss: 8.8256 - val_y1_output_root_mean_squared_error: 1.6920 - val_y2_output_root_mean_squared_error: 2.9448
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.1431 - y1_output_loss: 2.8655 - y2_output_loss: 5.3094 - y1_output_root_mean_squared_error: 1.6920 - y2_output_root_mean_squared_error: 2.2978 - val_loss: 21.0175 - val_y1_output_loss: 4.9470 - val_y2_output_loss: 16.0537 - val_y1_output_root_mean_squared_error: 2.2086 - val_y2_output_root_mean_squared_error: 4.0174
# Epoch 35/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.0206 - y1_output_loss: 2.9206 - y2_output_loss: 6.0882 - y1_output_root_mean_squared_error: 1.7151 - y2_output_root_mean_squared_error: 2.4656 - val_loss: 27.1515 - val_y1_output_loss: 5.5103 - val_y2_output_loss: 22.4306 - val_y1_output_root_mean_squared_error: 2.3372 - val_y2_output_root_mean_squared_error: 4.6572
# Epoch 36/500
# 614/614 [==============================] - 0s 151us/sample - loss: 9.6860 - y1_output_loss: 3.1674 - y2_output_loss: 6.5227 - y1_output_root_mean_squared_error: 1.7822 - y2_output_root_mean_squared_error: 2.5514 - val_loss: 9.2408 - val_y1_output_loss: 3.5152 - val_y2_output_loss: 5.5995 - val_y1_output_root_mean_squared_error: 1.8684 - val_y2_output_root_mean_squared_error: 2.3979
# Epoch 37/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.9065 - y1_output_loss: 3.3256 - y2_output_loss: 6.5994 - y1_output_root_mean_squared_error: 1.8162 - y2_output_root_mean_squared_error: 2.5706 - val_loss: 15.0834 - val_y1_output_loss: 7.0442 - val_y2_output_loss: 8.5261 - val_y1_output_root_mean_squared_error: 2.6043 - val_y2_output_root_mean_squared_error: 2.8811
# Epoch 38/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.4629 - y1_output_loss: 2.8407 - y2_output_loss: 5.5641 - y1_output_root_mean_squared_error: 1.6889 - y2_output_root_mean_squared_error: 2.3686 - val_loss: 8.8008 - val_y1_output_loss: 2.8462 - val_y2_output_loss: 6.0309 - val_y1_output_root_mean_squared_error: 1.6892 - val_y2_output_root_mean_squared_error: 2.4387
# Epoch 39/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5807 - y1_output_loss: 3.2329 - y2_output_loss: 6.2753 - y1_output_root_mean_squared_error: 1.8029 - y2_output_root_mean_squared_error: 2.5160 - val_loss: 10.7561 - val_y1_output_loss: 3.1797 - val_y2_output_loss: 7.7025 - val_y1_output_root_mean_squared_error: 1.7777 - val_y2_output_root_mean_squared_error: 2.7561
# Epoch 40/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.3699 - y1_output_loss: 2.6474 - y2_output_loss: 5.7440 - y1_output_root_mean_squared_error: 1.6208 - y2_output_root_mean_squared_error: 2.3964 - val_loss: 9.5407 - val_y1_output_loss: 3.2836 - val_y2_output_loss: 6.2904 - val_y1_output_root_mean_squared_error: 1.7922 - val_y2_output_root_mean_squared_error: 2.5157
# Epoch 41/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.3111 - y1_output_loss: 2.6367 - y2_output_loss: 5.5961 - y1_output_root_mean_squared_error: 1.6315 - y2_output_root_mean_squared_error: 2.3768 - val_loss: 6.6908 - val_y1_output_loss: 1.9763 - val_y2_output_loss: 4.7532 - val_y1_output_root_mean_squared_error: 1.4131 - val_y2_output_root_mean_squared_error: 2.1665
# Epoch 42/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.7992 - y1_output_loss: 2.5458 - y2_output_loss: 5.2217 - y1_output_root_mean_squared_error: 1.6020 - y2_output_root_mean_squared_error: 2.2875 - val_loss: 12.7222 - val_y1_output_loss: 3.0792 - val_y2_output_loss: 10.0563 - val_y1_output_root_mean_squared_error: 1.7447 - val_y2_output_root_mean_squared_error: 3.1110
# Epoch 43/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.5749 - y1_output_loss: 2.1255 - y2_output_loss: 4.4008 - y1_output_root_mean_squared_error: 1.4641 - y2_output_root_mean_squared_error: 2.1051 - val_loss: 11.8494 - val_y1_output_loss: 3.1739 - val_y2_output_loss: 9.0183 - val_y1_output_root_mean_squared_error: 1.7835 - val_y2_output_root_mean_squared_error: 2.9442
# Epoch 44/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.6771 - y1_output_loss: 2.4251 - y2_output_loss: 5.2180 - y1_output_root_mean_squared_error: 1.5618 - y2_output_root_mean_squared_error: 2.2887 - val_loss: 6.9115 - val_y1_output_loss: 2.3116 - val_y2_output_loss: 4.6712 - val_y1_output_root_mean_squared_error: 1.5175 - val_y2_output_root_mean_squared_error: 2.1468
# Epoch 45/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.3659 - y1_output_loss: 2.1518 - y2_output_loss: 4.2209 - y1_output_root_mean_squared_error: 1.4735 - y2_output_root_mean_squared_error: 2.0481 - val_loss: 14.3518 - val_y1_output_loss: 3.4547 - val_y2_output_loss: 11.4912 - val_y1_output_root_mean_squared_error: 1.8388 - val_y2_output_root_mean_squared_error: 3.3122
# Epoch 46/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.8758 - y1_output_loss: 2.1647 - y2_output_loss: 4.7167 - y1_output_root_mean_squared_error: 1.4717 - y2_output_root_mean_squared_error: 2.1702 - val_loss: 19.4595 - val_y1_output_loss: 5.0779 - val_y2_output_loss: 15.1299 - val_y1_output_root_mean_squared_error: 2.2268 - val_y2_output_root_mean_squared_error: 3.8080
# Epoch 47/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1911 - y1_output_loss: 2.1693 - y2_output_loss: 4.9925 - y1_output_root_mean_squared_error: 1.4782 - y2_output_root_mean_squared_error: 2.2374 - val_loss: 5.7738 - val_y1_output_loss: 1.6705 - val_y2_output_loss: 4.0884 - val_y1_output_root_mean_squared_error: 1.3006 - val_y2_output_root_mean_squared_error: 2.0204
# Epoch 48/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.9821 - y1_output_loss: 1.9269 - y2_output_loss: 4.0899 - y1_output_root_mean_squared_error: 1.3707 - y2_output_root_mean_squared_error: 2.0257 - val_loss: 10.4463 - val_y1_output_loss: 3.2007 - val_y2_output_loss: 7.7087 - val_y1_output_root_mean_squared_error: 1.7535 - val_y2_output_root_mean_squared_error: 2.7150
# Epoch 49/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.1898 - y1_output_loss: 2.5837 - y2_output_loss: 5.5661 - y1_output_root_mean_squared_error: 1.6134 - y2_output_root_mean_squared_error: 2.3636 - val_loss: 9.0272 - val_y1_output_loss: 1.8202 - val_y2_output_loss: 7.5699 - val_y1_output_root_mean_squared_error: 1.3490 - val_y2_output_root_mean_squared_error: 2.6847
# Epoch 50/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7015 - y1_output_loss: 1.7661 - y2_output_loss: 3.8888 - y1_output_root_mean_squared_error: 1.3349 - y2_output_root_mean_squared_error: 1.9798 - val_loss: 5.8857 - val_y1_output_loss: 1.5603 - val_y2_output_loss: 4.4280 - val_y1_output_root_mean_squared_error: 1.2525 - val_y2_output_root_mean_squared_error: 2.0777
# Epoch 51/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.6070 - y1_output_loss: 1.6769 - y2_output_loss: 3.9252 - y1_output_root_mean_squared_error: 1.2937 - y2_output_root_mean_squared_error: 1.9833 - val_loss: 8.3208 - val_y1_output_loss: 1.9148 - val_y2_output_loss: 6.2098 - val_y1_output_root_mean_squared_error: 1.3965 - val_y2_output_root_mean_squared_error: 2.5240
# Epoch 52/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.9563 - y1_output_loss: 1.7528 - y2_output_loss: 4.2224 - y1_output_root_mean_squared_error: 1.3150 - y2_output_root_mean_squared_error: 2.0560 - val_loss: 8.2890 - val_y1_output_loss: 2.9121 - val_y2_output_loss: 5.2956 - val_y1_output_root_mean_squared_error: 1.6964 - val_y2_output_root_mean_squared_error: 2.3262
# Epoch 53/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.3671 - y1_output_loss: 1.8974 - y2_output_loss: 4.5217 - y1_output_root_mean_squared_error: 1.3701 - y2_output_root_mean_squared_error: 2.1189 - val_loss: 9.6473 - val_y1_output_loss: 2.7677 - val_y2_output_loss: 6.6856 - val_y1_output_root_mean_squared_error: 1.6608 - val_y2_output_root_mean_squared_error: 2.6247
# Epoch 54/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.1843 - y1_output_loss: 1.5352 - y2_output_loss: 3.6827 - y1_output_root_mean_squared_error: 1.2240 - y2_output_root_mean_squared_error: 1.9199 - val_loss: 6.5768 - val_y1_output_loss: 1.9631 - val_y2_output_loss: 4.4888 - val_y1_output_root_mean_squared_error: 1.4097 - val_y2_output_root_mean_squared_error: 2.1423
# Epoch 55/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.5756 - y1_output_loss: 1.5282 - y2_output_loss: 4.0530 - y1_output_root_mean_squared_error: 1.2338 - y2_output_root_mean_squared_error: 2.0133 - val_loss: 5.4537 - val_y1_output_loss: 1.7791 - val_y2_output_loss: 3.7646 - val_y1_output_root_mean_squared_error: 1.3274 - val_y2_output_root_mean_squared_error: 1.9214
# Epoch 56/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3340 - y1_output_loss: 1.4186 - y2_output_loss: 3.9226 - y1_output_root_mean_squared_error: 1.1919 - y2_output_root_mean_squared_error: 1.9782 - val_loss: 7.0758 - val_y1_output_loss: 1.6762 - val_y2_output_loss: 5.3921 - val_y1_output_root_mean_squared_error: 1.2952 - val_y2_output_root_mean_squared_error: 2.3234
# Epoch 57/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.7092 - y1_output_loss: 2.1392 - y2_output_loss: 5.5706 - y1_output_root_mean_squared_error: 1.4677 - y2_output_root_mean_squared_error: 2.3569 - val_loss: 5.9405 - val_y1_output_loss: 2.0266 - val_y2_output_loss: 4.1073 - val_y1_output_root_mean_squared_error: 1.4049 - val_y2_output_root_mean_squared_error: 1.9917
# Epoch 58/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.1655 - y1_output_loss: 1.8059 - y2_output_loss: 4.3757 - y1_output_root_mean_squared_error: 1.3468 - y2_output_root_mean_squared_error: 2.0861 - val_loss: 12.3041 - val_y1_output_loss: 3.5408 - val_y2_output_loss: 9.2498 - val_y1_output_root_mean_squared_error: 1.8200 - val_y2_output_root_mean_squared_error: 2.9986
# Epoch 59/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1604 - y1_output_loss: 1.3623 - y2_output_loss: 3.7497 - y1_output_root_mean_squared_error: 1.1728 - y2_output_root_mean_squared_error: 1.9455 - val_loss: 3.8631 - val_y1_output_loss: 0.9685 - val_y2_output_loss: 2.9360 - val_y1_output_root_mean_squared_error: 0.9877 - val_y2_output_root_mean_squared_error: 1.6993
# Epoch 60/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7295 - y1_output_loss: 1.3949 - y2_output_loss: 4.3460 - y1_output_root_mean_squared_error: 1.1755 - y2_output_root_mean_squared_error: 2.0851 - val_loss: 7.1974 - val_y1_output_loss: 2.3397 - val_y2_output_loss: 4.7389 - val_y1_output_root_mean_squared_error: 1.5160 - val_y2_output_root_mean_squared_error: 2.2134
# Epoch 61/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.8020 - y1_output_loss: 1.5029 - y2_output_loss: 4.2454 - y1_output_root_mean_squared_error: 1.2315 - y2_output_root_mean_squared_error: 2.0701 - val_loss: 4.2020 - val_y1_output_loss: 1.0512 - val_y2_output_loss: 3.3244 - val_y1_output_root_mean_squared_error: 1.0128 - val_y2_output_root_mean_squared_error: 1.7822
# Epoch 62/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.4701 - y1_output_loss: 1.2324 - y2_output_loss: 3.2303 - y1_output_root_mean_squared_error: 1.1107 - y2_output_root_mean_squared_error: 1.7990 - val_loss: 9.4735 - val_y1_output_loss: 2.7064 - val_y2_output_loss: 7.4076 - val_y1_output_root_mean_squared_error: 1.6041 - val_y2_output_root_mean_squared_error: 2.6269
# Epoch 63/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.4839 - y1_output_loss: 1.2617 - y2_output_loss: 3.2064 - y1_output_root_mean_squared_error: 1.1259 - y2_output_root_mean_squared_error: 1.7934 - val_loss: 4.3664 - val_y1_output_loss: 1.1980 - val_y2_output_loss: 3.1393 - val_y1_output_root_mean_squared_error: 1.0867 - val_y2_output_root_mean_squared_error: 1.7848
# Epoch 64/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.2850 - y1_output_loss: 1.0938 - y2_output_loss: 3.1748 - y1_output_root_mean_squared_error: 1.0447 - y2_output_root_mean_squared_error: 1.7870 - val_loss: 4.2922 - val_y1_output_loss: 1.3195 - val_y2_output_loss: 2.9323 - val_y1_output_root_mean_squared_error: 1.1507 - val_y2_output_root_mean_squared_error: 1.7228
# Epoch 65/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.7301 - y1_output_loss: 1.1697 - y2_output_loss: 3.5230 - y1_output_root_mean_squared_error: 1.0859 - y2_output_root_mean_squared_error: 1.8844 - val_loss: 4.0374 - val_y1_output_loss: 0.9873 - val_y2_output_loss: 3.2210 - val_y1_output_root_mean_squared_error: 0.9838 - val_y2_output_root_mean_squared_error: 1.7520
# Epoch 66/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.5698 - y1_output_loss: 1.0219 - y2_output_loss: 3.5365 - y1_output_root_mean_squared_error: 1.0145 - y2_output_root_mean_squared_error: 1.8817 - val_loss: 5.7860 - val_y1_output_loss: 1.2886 - val_y2_output_loss: 4.5586 - val_y1_output_root_mean_squared_error: 1.1272 - val_y2_output_root_mean_squared_error: 2.1250
# Epoch 67/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.5669 - y1_output_loss: 1.1310 - y2_output_loss: 3.4556 - y1_output_root_mean_squared_error: 1.0538 - y2_output_root_mean_squared_error: 1.8591 - val_loss: 6.6580 - val_y1_output_loss: 1.4405 - val_y2_output_loss: 5.5467 - val_y1_output_root_mean_squared_error: 1.2028 - val_y2_output_root_mean_squared_error: 2.2828
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.3012 - y1_output_loss: 1.0184 - y2_output_loss: 3.3159 - y1_output_root_mean_squared_error: 1.0101 - y2_output_root_mean_squared_error: 1.8113 - val_loss: 10.2536 - val_y1_output_loss: 1.9801 - val_y2_output_loss: 8.8976 - val_y1_output_root_mean_squared_error: 1.3930 - val_y2_output_root_mean_squared_error: 2.8832
# Epoch 69/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.5101 - y1_output_loss: 1.0056 - y2_output_loss: 3.6234 - y1_output_root_mean_squared_error: 0.9961 - y2_output_root_mean_squared_error: 1.8756 - val_loss: 8.9830 - val_y1_output_loss: 3.4036 - val_y2_output_loss: 5.7737 - val_y1_output_root_mean_squared_error: 1.7724 - val_y2_output_root_mean_squared_error: 2.4169
# Epoch 70/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.3713 - y1_output_loss: 1.7893 - y2_output_loss: 4.5808 - y1_output_root_mean_squared_error: 1.3372 - y2_output_root_mean_squared_error: 2.1409 - val_loss: 6.9897 - val_y1_output_loss: 0.8113 - val_y2_output_loss: 6.0600 - val_y1_output_root_mean_squared_error: 0.8902 - val_y2_output_root_mean_squared_error: 2.4894
# Epoch 71/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.1373 - y1_output_loss: 0.8931 - y2_output_loss: 3.2538 - y1_output_root_mean_squared_error: 0.9486 - y2_output_root_mean_squared_error: 1.7993 - val_loss: 3.3922 - val_y1_output_loss: 0.7667 - val_y2_output_loss: 2.6254 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.6267
# Epoch 72/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.2842 - y1_output_loss: 1.5029 - y2_output_loss: 3.7532 - y1_output_root_mean_squared_error: 1.2315 - y2_output_root_mean_squared_error: 1.9410 - val_loss: 3.5274 - val_y1_output_loss: 0.8957 - val_y2_output_loss: 2.6417 - val_y1_output_root_mean_squared_error: 0.9336 - val_y2_output_root_mean_squared_error: 1.6297
# Epoch 73/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.0808 - y1_output_loss: 3.3583 - y2_output_loss: 7.6665 - y1_output_root_mean_squared_error: 1.8349 - y2_output_root_mean_squared_error: 2.7774 - val_loss: 3.7027 - val_y1_output_loss: 1.0945 - val_y2_output_loss: 2.6777 - val_y1_output_root_mean_squared_error: 1.0067 - val_y2_output_root_mean_squared_error: 1.6399
# Epoch 74/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.9651 - y1_output_loss: 1.3138 - y2_output_loss: 3.6481 - y1_output_root_mean_squared_error: 1.1475 - y2_output_root_mean_squared_error: 1.9101 - val_loss: 4.2748 - val_y1_output_loss: 0.9652 - val_y2_output_loss: 3.3187 - val_y1_output_root_mean_squared_error: 0.9676 - val_y2_output_root_mean_squared_error: 1.8272
# Epoch 75/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.6383 - y1_output_loss: 0.9109 - y2_output_loss: 2.7525 - y1_output_root_mean_squared_error: 0.9519 - y2_output_root_mean_squared_error: 1.6529 - val_loss: 6.1209 - val_y1_output_loss: 1.0365 - val_y2_output_loss: 5.4292 - val_y1_output_root_mean_squared_error: 1.0127 - val_y2_output_root_mean_squared_error: 2.2573
# Epoch 76/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.5388 - y1_output_loss: 0.7575 - y2_output_loss: 2.7486 - y1_output_root_mean_squared_error: 0.8742 - y2_output_root_mean_squared_error: 1.6657 - val_loss: 3.0080 - val_y1_output_loss: 0.9127 - val_y2_output_loss: 2.2420 - val_y1_output_root_mean_squared_error: 0.9239 - val_y2_output_root_mean_squared_error: 1.4678
# Epoch 77/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.7471 - y1_output_loss: 1.2163 - y2_output_loss: 3.4942 - y1_output_root_mean_squared_error: 1.1058 - y2_output_root_mean_squared_error: 1.8773 - val_loss: 3.3250 - val_y1_output_loss: 0.8616 - val_y2_output_loss: 2.5178 - val_y1_output_root_mean_squared_error: 0.9158 - val_y2_output_root_mean_squared_error: 1.5768
# Epoch 78/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5398 - y1_output_loss: 0.7994 - y2_output_loss: 2.7453 - y1_output_root_mean_squared_error: 0.8957 - y2_output_root_mean_squared_error: 1.6545 - val_loss: 6.7266 - val_y1_output_loss: 1.8304 - val_y2_output_loss: 5.0857 - val_y1_output_root_mean_squared_error: 1.3263 - val_y2_output_root_mean_squared_error: 2.2288
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.9350 - y1_output_loss: 0.9701 - y2_output_loss: 2.9336 - y1_output_root_mean_squared_error: 0.9892 - y2_output_root_mean_squared_error: 1.7194 - val_loss: 2.8155 - val_y1_output_loss: 0.7098 - val_y2_output_loss: 2.2644 - val_y1_output_root_mean_squared_error: 0.8162 - val_y2_output_root_mean_squared_error: 1.4660
# Epoch 80/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.3333 - y1_output_loss: 0.9161 - y2_output_loss: 3.3886 - y1_output_root_mean_squared_error: 0.9587 - y2_output_root_mean_squared_error: 1.8478 - val_loss: 3.8143 - val_y1_output_loss: 1.0096 - val_y2_output_loss: 2.9972 - val_y1_output_root_mean_squared_error: 1.0096 - val_y2_output_root_mean_squared_error: 1.6719
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.5859 - y1_output_loss: 0.8245 - y2_output_loss: 2.7283 - y1_output_root_mean_squared_error: 0.9124 - y2_output_root_mean_squared_error: 1.6594 - val_loss: 3.1656 - val_y1_output_loss: 0.5991 - val_y2_output_loss: 2.8211 - val_y1_output_root_mean_squared_error: 0.7598 - val_y2_output_root_mean_squared_error: 1.6088
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0675 - y1_output_loss: 0.6831 - y2_output_loss: 2.3843 - y1_output_root_mean_squared_error: 0.8229 - y2_output_root_mean_squared_error: 1.5460 - val_loss: 3.5969 - val_y1_output_loss: 1.4058 - val_y2_output_loss: 2.3547 - val_y1_output_root_mean_squared_error: 1.1389 - val_y2_output_root_mean_squared_error: 1.5165
# Epoch 83/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.3293 - y1_output_loss: 0.8324 - y2_output_loss: 2.6656 - y1_output_root_mean_squared_error: 0.8847 - y2_output_root_mean_squared_error: 1.5958 - val_loss: 27.2591 - val_y1_output_loss: 7.7465 - val_y2_output_loss: 20.6142 - val_y1_output_root_mean_squared_error: 2.6817 - val_y2_output_root_mean_squared_error: 4.4797
# Epoch 84/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.0365 - y1_output_loss: 0.9585 - y2_output_loss: 3.0634 - y1_output_root_mean_squared_error: 0.9804 - y2_output_root_mean_squared_error: 1.7536 - val_loss: 3.3359 - val_y1_output_loss: 0.6327 - val_y2_output_loss: 2.9556 - val_y1_output_root_mean_squared_error: 0.7912 - val_y2_output_root_mean_squared_error: 1.6462
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2503 - y1_output_loss: 0.9810 - y2_output_loss: 3.2608 - y1_output_root_mean_squared_error: 0.9884 - y2_output_root_mean_squared_error: 1.8093 - val_loss: 3.0794 - val_y1_output_loss: 0.6355 - val_y2_output_loss: 2.5047 - val_y1_output_root_mean_squared_error: 0.7690 - val_y2_output_root_mean_squared_error: 1.5774
# Epoch 86/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6116 - y1_output_loss: 0.7441 - y2_output_loss: 2.8450 - y1_output_root_mean_squared_error: 0.8661 - y2_output_root_mean_squared_error: 1.6916 - val_loss: 3.4233 - val_y1_output_loss: 0.6632 - val_y2_output_loss: 2.7946 - val_y1_output_root_mean_squared_error: 0.8088 - val_y2_output_root_mean_squared_error: 1.6641
# Epoch 87/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.1843 - y1_output_loss: 0.6528 - y2_output_loss: 2.5325 - y1_output_root_mean_squared_error: 0.7998 - y2_output_root_mean_squared_error: 1.5952 - val_loss: 3.7271 - val_y1_output_loss: 0.8467 - val_y2_output_loss: 2.9877 - val_y1_output_root_mean_squared_error: 0.9066 - val_y2_output_root_mean_squared_error: 1.7045
# Epoch 88/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8040 - y1_output_loss: 0.5472 - y2_output_loss: 2.2823 - y1_output_root_mean_squared_error: 0.7413 - y2_output_root_mean_squared_error: 1.5015 - val_loss: 5.3733 - val_y1_output_loss: 0.8456 - val_y2_output_loss: 4.4856 - val_y1_output_root_mean_squared_error: 0.8994 - val_y2_output_root_mean_squared_error: 2.1364
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4147 - y1_output_loss: 0.7227 - y2_output_loss: 2.7274 - y1_output_root_mean_squared_error: 0.8518 - y2_output_root_mean_squared_error: 1.6399 - val_loss: 12.1219 - val_y1_output_loss: 2.2076 - val_y2_output_loss: 10.7660 - val_y1_output_root_mean_squared_error: 1.4472 - val_y2_output_root_mean_squared_error: 3.1666
# Epoch 90/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2726 - y1_output_loss: 0.6811 - y2_output_loss: 2.5769 - y1_output_root_mean_squared_error: 0.8264 - y2_output_root_mean_squared_error: 1.6092 - val_loss: 3.7727 - val_y1_output_loss: 1.2650 - val_y2_output_loss: 2.6321 - val_y1_output_root_mean_squared_error: 1.0965 - val_y2_output_root_mean_squared_error: 1.6032
# Epoch 91/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2759 - y1_output_loss: 0.8044 - y2_output_loss: 2.4721 - y1_output_root_mean_squared_error: 0.8954 - y2_output_root_mean_squared_error: 1.5729 - val_loss: 2.5306 - val_y1_output_loss: 0.5165 - val_y2_output_loss: 2.1174 - val_y1_output_root_mean_squared_error: 0.7107 - val_y2_output_root_mean_squared_error: 1.4232
# Epoch 92/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.1230 - y1_output_loss: 0.9501 - y2_output_loss: 3.1842 - y1_output_root_mean_squared_error: 0.9636 - y2_output_root_mean_squared_error: 1.7873 - val_loss: 3.1131 - val_y1_output_loss: 0.6261 - val_y2_output_loss: 2.5277 - val_y1_output_root_mean_squared_error: 0.7870 - val_y2_output_root_mean_squared_error: 1.5792
# Epoch 93/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.9464 - y1_output_loss: 0.6200 - y2_output_loss: 2.3633 - y1_output_root_mean_squared_error: 0.7831 - y2_output_root_mean_squared_error: 1.5275 - val_loss: 9.2124 - val_y1_output_loss: 4.3028 - val_y2_output_loss: 5.4602 - val_y1_output_root_mean_squared_error: 2.0058 - val_y2_output_root_mean_squared_error: 2.2780
# Epoch 94/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4975 - y1_output_loss: 0.5721 - y2_output_loss: 1.9406 - y1_output_root_mean_squared_error: 0.7565 - y2_output_root_mean_squared_error: 1.3876 - val_loss: 2.9142 - val_y1_output_loss: 0.5503 - val_y2_output_loss: 2.6144 - val_y1_output_root_mean_squared_error: 0.7315 - val_y2_output_root_mean_squared_error: 1.5424
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1679 - y1_output_loss: 0.6173 - y2_output_loss: 2.5495 - y1_output_root_mean_squared_error: 0.7835 - y2_output_root_mean_squared_error: 1.5982 - val_loss: 4.1449 - val_y1_output_loss: 0.7759 - val_y2_output_loss: 3.7065 - val_y1_output_root_mean_squared_error: 0.8695 - val_y2_output_root_mean_squared_error: 1.8409
# Epoch 96/500
# 614/614 [==============================] - 0s 186us/sample - loss: 2.8392 - y1_output_loss: 0.5387 - y2_output_loss: 2.2926 - y1_output_root_mean_squared_error: 0.7357 - y2_output_root_mean_squared_error: 1.5159 - val_loss: 6.1161 - val_y1_output_loss: 0.8560 - val_y2_output_loss: 5.8267 - val_y1_output_root_mean_squared_error: 0.9111 - val_y2_output_root_mean_squared_error: 2.2991
# Epoch 97/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.6704 - y1_output_loss: 0.9773 - y2_output_loss: 2.6763 - y1_output_root_mean_squared_error: 0.9916 - y2_output_root_mean_squared_error: 1.6392 - val_loss: 2.9558 - val_y1_output_loss: 0.7044 - val_y2_output_loss: 2.5193 - val_y1_output_root_mean_squared_error: 0.8131 - val_y2_output_root_mean_squared_error: 1.5148
# Epoch 98/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6286 - y1_output_loss: 0.6258 - y2_output_loss: 2.0291 - y1_output_root_mean_squared_error: 0.7881 - y2_output_root_mean_squared_error: 1.4168 - val_loss: 8.1813 - val_y1_output_loss: 2.0560 - val_y2_output_loss: 6.2118 - val_y1_output_root_mean_squared_error: 1.4116 - val_y2_output_root_mean_squared_error: 2.4877
# Epoch 99/500
# 614/614 [==============================] - 0s 190us/sample - loss: 7.2735 - y1_output_loss: 1.8893 - y2_output_loss: 5.3252 - y1_output_root_mean_squared_error: 1.3787 - y2_output_root_mean_squared_error: 2.3179 - val_loss: 2.8568 - val_y1_output_loss: 0.7369 - val_y2_output_loss: 2.2102 - val_y1_output_root_mean_squared_error: 0.8436 - val_y2_output_root_mean_squared_error: 1.4646
# Epoch 100/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4991 - y1_output_loss: 0.5420 - y2_output_loss: 1.9548 - y1_output_root_mean_squared_error: 0.7378 - y2_output_root_mean_squared_error: 1.3981 - val_loss: 5.3854 - val_y1_output_loss: 0.5009 - val_y2_output_loss: 5.4245 - val_y1_output_root_mean_squared_error: 0.6951 - val_y2_output_root_mean_squared_error: 2.2141
# Epoch 101/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5752 - y1_output_loss: 0.8435 - y2_output_loss: 2.7152 - y1_output_root_mean_squared_error: 0.9226 - y2_output_root_mean_squared_error: 1.6505 - val_loss: 3.4829 - val_y1_output_loss: 1.0746 - val_y2_output_loss: 2.4280 - val_y1_output_root_mean_squared_error: 1.0070 - val_y2_output_root_mean_squared_error: 1.5713
# Epoch 102/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7546 - y1_output_loss: 0.6030 - y2_output_loss: 2.1652 - y1_output_root_mean_squared_error: 0.7796 - y2_output_root_mean_squared_error: 1.4652 - val_loss: 9.2469 - val_y1_output_loss: 2.4473 - val_y2_output_loss: 7.0282 - val_y1_output_root_mean_squared_error: 1.5279 - val_y2_output_root_mean_squared_error: 2.6292
# Epoch 103/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.2001 - y1_output_loss: 0.9598 - y2_output_loss: 3.2463 - y1_output_root_mean_squared_error: 0.9817 - y2_output_root_mean_squared_error: 1.7990 - val_loss: 2.1903 - val_y1_output_loss: 0.5225 - val_y2_output_loss: 1.7728 - val_y1_output_root_mean_squared_error: 0.7081 - val_y2_output_root_mean_squared_error: 1.2996
# Epoch 104/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.4510 - y1_output_loss: 0.5033 - y2_output_loss: 1.9311 - y1_output_root_mean_squared_error: 0.7117 - y2_output_root_mean_squared_error: 1.3944 - val_loss: 2.9431 - val_y1_output_loss: 0.8192 - val_y2_output_loss: 2.2234 - val_y1_output_root_mean_squared_error: 0.8794 - val_y2_output_root_mean_squared_error: 1.4730
# Epoch 105/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.5327 - y1_output_loss: 0.5246 - y2_output_loss: 2.0059 - y1_output_root_mean_squared_error: 0.7260 - y2_output_root_mean_squared_error: 1.4162 - val_loss: 3.1402 - val_y1_output_loss: 0.4337 - val_y2_output_loss: 3.0513 - val_y1_output_root_mean_squared_error: 0.6579 - val_y2_output_root_mean_squared_error: 1.6454
# Epoch 106/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6747 - y1_output_loss: 0.5839 - y2_output_loss: 2.0942 - y1_output_root_mean_squared_error: 0.7672 - y2_output_root_mean_squared_error: 1.4443 - val_loss: 4.0845 - val_y1_output_loss: 0.9701 - val_y2_output_loss: 3.1380 - val_y1_output_root_mean_squared_error: 0.9626 - val_y2_output_root_mean_squared_error: 1.7770
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.2245 - y1_output_loss: 0.5247 - y2_output_loss: 1.6925 - y1_output_root_mean_squared_error: 0.7257 - y2_output_root_mean_squared_error: 1.3030 - val_loss: 2.5066 - val_y1_output_loss: 0.4896 - val_y2_output_loss: 2.1192 - val_y1_output_root_mean_squared_error: 0.6871 - val_y2_output_root_mean_squared_error: 1.4264
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4782 - y1_output_loss: 0.5176 - y2_output_loss: 1.9589 - y1_output_root_mean_squared_error: 0.7175 - y2_output_root_mean_squared_error: 1.4012 - val_loss: 4.6580 - val_y1_output_loss: 1.3632 - val_y2_output_loss: 3.5185 - val_y1_output_root_mean_squared_error: 1.1488 - val_y2_output_root_mean_squared_error: 1.8271
# Epoch 109/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.3894 - y1_output_loss: 1.2162 - y2_output_loss: 3.1566 - y1_output_root_mean_squared_error: 1.1018 - y2_output_root_mean_squared_error: 1.7820 - val_loss: 10.0491 - val_y1_output_loss: 3.1331 - val_y2_output_loss: 7.8260 - val_y1_output_root_mean_squared_error: 1.7207 - val_y2_output_root_mean_squared_error: 2.6624
# Epoch 110/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7520 - y1_output_loss: 0.6644 - y2_output_loss: 2.0761 - y1_output_root_mean_squared_error: 0.8177 - y2_output_root_mean_squared_error: 1.4434 - val_loss: 3.5226 - val_y1_output_loss: 0.8607 - val_y2_output_loss: 3.1155 - val_y1_output_root_mean_squared_error: 0.8932 - val_y2_output_root_mean_squared_error: 1.6507
# Epoch 111/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.0751 - y1_output_loss: 0.4642 - y2_output_loss: 1.5979 - y1_output_root_mean_squared_error: 0.6825 - y2_output_root_mean_squared_error: 1.2686 - val_loss: 3.3066 - val_y1_output_loss: 0.4168 - val_y2_output_loss: 3.2622 - val_y1_output_root_mean_squared_error: 0.6491 - val_y2_output_root_mean_squared_error: 1.6986
# Epoch 112/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.7796 - y1_output_loss: 0.5806 - y2_output_loss: 2.1886 - y1_output_root_mean_squared_error: 0.7615 - y2_output_root_mean_squared_error: 1.4831 - val_loss: 2.6868 - val_y1_output_loss: 0.9052 - val_y2_output_loss: 1.9023 - val_y1_output_root_mean_squared_error: 0.9288 - val_y2_output_root_mean_squared_error: 1.3506
# Epoch 113/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.4642 - y1_output_loss: 0.5782 - y2_output_loss: 1.8728 - y1_output_root_mean_squared_error: 0.7626 - y2_output_root_mean_squared_error: 1.3721 - val_loss: 2.2413 - val_y1_output_loss: 0.4972 - val_y2_output_loss: 1.9586 - val_y1_output_root_mean_squared_error: 0.6827 - val_y2_output_root_mean_squared_error: 1.3323
# Epoch 114/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.5595 - y1_output_loss: 0.6234 - y2_output_loss: 1.9278 - y1_output_root_mean_squared_error: 0.7907 - y2_output_root_mean_squared_error: 1.3908 - val_loss: 2.7773 - val_y1_output_loss: 0.5938 - val_y2_output_loss: 2.5177 - val_y1_output_root_mean_squared_error: 0.7593 - val_y2_output_root_mean_squared_error: 1.4835
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6640 - y1_output_loss: 0.5989 - y2_output_loss: 2.0479 - y1_output_root_mean_squared_error: 0.7767 - y2_output_root_mean_squared_error: 1.4355 - val_loss: 2.2726 - val_y1_output_loss: 0.5449 - val_y2_output_loss: 1.9061 - val_y1_output_root_mean_squared_error: 0.7328 - val_y2_output_root_mean_squared_error: 1.3174
# Epoch 116/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.1986 - y1_output_loss: 0.4842 - y2_output_loss: 1.7111 - y1_output_root_mean_squared_error: 0.6969 - y2_output_root_mean_squared_error: 1.3088 - val_loss: 2.1791 - val_y1_output_loss: 0.3931 - val_y2_output_loss: 2.0655 - val_y1_output_root_mean_squared_error: 0.6230 - val_y2_output_root_mean_squared_error: 1.3383
# Epoch 117/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4844 - y1_output_loss: 0.5325 - y2_output_loss: 1.9460 - y1_output_root_mean_squared_error: 0.7327 - y2_output_root_mean_squared_error: 1.3956 - val_loss: 3.7189 - val_y1_output_loss: 0.5205 - val_y2_output_loss: 3.2112 - val_y1_output_root_mean_squared_error: 0.7071 - val_y2_output_root_mean_squared_error: 1.7941
# Epoch 118/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0103 - y1_output_loss: 0.7717 - y2_output_loss: 2.2217 - y1_output_root_mean_squared_error: 0.8821 - y2_output_root_mean_squared_error: 1.4941 - val_loss: 2.5723 - val_y1_output_loss: 0.7427 - val_y2_output_loss: 2.0430 - val_y1_output_root_mean_squared_error: 0.8382 - val_y2_output_root_mean_squared_error: 1.3674
# Epoch 119/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.2281 - y1_output_loss: 0.4662 - y2_output_loss: 1.7486 - y1_output_root_mean_squared_error: 0.6847 - y2_output_root_mean_squared_error: 1.3264 - val_loss: 2.2190 - val_y1_output_loss: 0.5924 - val_y2_output_loss: 1.8880 - val_y1_output_root_mean_squared_error: 0.7418 - val_y2_output_root_mean_squared_error: 1.2918
# Epoch 120/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.8594 - y1_output_loss: 0.3957 - y2_output_loss: 1.4595 - y1_output_root_mean_squared_error: 0.6293 - y2_output_root_mean_squared_error: 1.2097 - val_loss: 2.8389 - val_y1_output_loss: 0.6073 - val_y2_output_loss: 2.6134 - val_y1_output_root_mean_squared_error: 0.7447 - val_y2_output_root_mean_squared_error: 1.5114
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2731 - y1_output_loss: 0.0883 - y2_output_loss: 0.1828 - y1_output_root_mean_squared_error: 0.2982 - y2_output_root_mean_squared_error: 0.4291 - val_loss: 0.6638 - val_y1_output_loss: 0.2175 - val_y2_output_loss: 0.4581 - val_y1_output_root_mean_squared_error: 0.4602 - val_y2_output_root_mean_squared_error: 0.6723
# Epoch 462/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3164 - y1_output_loss: 0.1142 - y2_output_loss: 0.2045 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.4501 - val_loss: 0.9310 - val_y1_output_loss: 0.3669 - val_y2_output_loss: 0.5981 - val_y1_output_root_mean_squared_error: 0.5927 - val_y2_output_root_mean_squared_error: 0.7613
# Epoch 463/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2793 - y1_output_loss: 0.1010 - y2_output_loss: 0.1762 - y1_output_root_mean_squared_error: 0.3189 - y2_output_root_mean_squared_error: 0.4215 - val_loss: 0.6523 - val_y1_output_loss: 0.1759 - val_y2_output_loss: 0.4862 - val_y1_output_root_mean_squared_error: 0.4174 - val_y2_output_root_mean_squared_error: 0.6915
# Epoch 464/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3422 - y1_output_loss: 0.1049 - y2_output_loss: 0.2400 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.4880 - val_loss: 1.0989 - val_y1_output_loss: 0.3089 - val_y2_output_loss: 0.7887 - val_y1_output_root_mean_squared_error: 0.5531 - val_y2_output_root_mean_squared_error: 0.8905
# Epoch 465/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2830 - y1_output_loss: 0.1105 - y2_output_loss: 0.1701 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.4140 - val_loss: 0.8187 - val_y1_output_loss: 0.2151 - val_y2_output_loss: 0.5972 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 0.7807
# Epoch 466/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4635 - y1_output_loss: 0.1248 - y2_output_loss: 0.3347 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.5812 - val_loss: 0.6734 - val_y1_output_loss: 0.2103 - val_y2_output_loss: 0.4720 - val_y1_output_root_mean_squared_error: 0.4518 - val_y2_output_root_mean_squared_error: 0.6851
# Epoch 467/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4085 - y1_output_loss: 0.1179 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5384 - val_loss: 0.7542 - val_y1_output_loss: 0.2442 - val_y2_output_loss: 0.5201 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.7186
# Epoch 468/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3877 - y1_output_loss: 0.1169 - y2_output_loss: 0.2693 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5205 - val_loss: 0.7071 - val_y1_output_loss: 0.2030 - val_y2_output_loss: 0.5265 - val_y1_output_root_mean_squared_error: 0.4466 - val_y2_output_root_mean_squared_error: 0.7125
# Epoch 469/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.2458 - y1_output_loss: 0.1044 - y2_output_loss: 0.1462 - y1_output_root_mean_squared_error: 0.3170 - y2_output_root_mean_squared_error: 0.3812 - val_loss: 0.9723 - val_y1_output_loss: 0.4216 - val_y2_output_loss: 0.5673 - val_y1_output_root_mean_squared_error: 0.6316 - val_y2_output_root_mean_squared_error: 0.7573
# Epoch 470/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3177 - y1_output_loss: 0.1009 - y2_output_loss: 0.2140 - y1_output_root_mean_squared_error: 0.3187 - y2_output_root_mean_squared_error: 0.4648 - val_loss: 0.6813 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 0.5249 - val_y1_output_root_mean_squared_error: 0.4229 - val_y2_output_root_mean_squared_error: 0.7089
# Epoch 471/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.3768 - y1_output_loss: 0.1407 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.4852 - val_loss: 0.6942 - val_y1_output_loss: 0.1983 - val_y2_output_loss: 0.4995 - val_y1_output_root_mean_squared_error: 0.4434 - val_y2_output_root_mean_squared_error: 0.7054
# Epoch 472/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3115 - y1_output_loss: 0.1143 - y2_output_loss: 0.1948 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4434 - val_loss: 0.7007 - val_y1_output_loss: 0.2385 - val_y2_output_loss: 0.4845 - val_y1_output_root_mean_squared_error: 0.4800 - val_y2_output_root_mean_squared_error: 0.6858
# Epoch 473/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4479 - y1_output_loss: 0.1476 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3849 - y2_output_root_mean_squared_error: 0.5475 - val_loss: 0.6932 - val_y1_output_loss: 0.2325 - val_y2_output_loss: 0.4767 - val_y1_output_root_mean_squared_error: 0.4736 - val_y2_output_root_mean_squared_error: 0.6848
# Epoch 474/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2508 - y1_output_loss: 0.0914 - y2_output_loss: 0.1583 - y1_output_root_mean_squared_error: 0.3035 - y2_output_root_mean_squared_error: 0.3984 - val_loss: 0.6676 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.4704 - val_y1_output_root_mean_squared_error: 0.4400 - val_y2_output_root_mean_squared_error: 0.6884
# Epoch 475/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3240 - y1_output_loss: 0.1075 - y2_output_loss: 0.2153 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4650 - val_loss: 0.7579 - val_y1_output_loss: 0.2205 - val_y2_output_loss: 0.5731 - val_y1_output_root_mean_squared_error: 0.4648 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 476/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2693 - y1_output_loss: 0.1002 - y2_output_loss: 0.1677 - y1_output_root_mean_squared_error: 0.3178 - y2_output_root_mean_squared_error: 0.4103 - val_loss: 0.7413 - val_y1_output_loss: 0.2145 - val_y2_output_loss: 0.5326 - val_y1_output_root_mean_squared_error: 0.4582 - val_y2_output_root_mean_squared_error: 0.7289
# Epoch 477/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2856 - y1_output_loss: 0.1123 - y2_output_loss: 0.1720 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4156 - val_loss: 0.7375 - val_y1_output_loss: 0.2238 - val_y2_output_loss: 0.5120 - val_y1_output_root_mean_squared_error: 0.4668 - val_y2_output_root_mean_squared_error: 0.7209
# Epoch 478/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5397 - y1_output_loss: 0.1808 - y2_output_loss: 0.3575 - y1_output_root_mean_squared_error: 0.4257 - y2_output_root_mean_squared_error: 0.5988 - val_loss: 1.0873 - val_y1_output_loss: 0.3364 - val_y2_output_loss: 0.8385 - val_y1_output_root_mean_squared_error: 0.5677 - val_y2_output_root_mean_squared_error: 0.8747
# Epoch 479/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3257 - y1_output_loss: 0.1184 - y2_output_loss: 0.2126 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.4554 - val_loss: 1.6301 - val_y1_output_loss: 0.4143 - val_y2_output_loss: 1.2112 - val_y1_output_root_mean_squared_error: 0.6327 - val_y2_output_root_mean_squared_error: 1.1090
# Epoch 480/500
# 614/614 [==============================] - 0s 192us/sample - loss: 0.3142 - y1_output_loss: 0.1028 - y2_output_loss: 0.2100 - y1_output_root_mean_squared_error: 0.3210 - y2_output_root_mean_squared_error: 0.4596 - val_loss: 0.6983 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 0.5039 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.7026
# Epoch 481/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2679 - y1_output_loss: 0.0978 - y2_output_loss: 0.1740 - y1_output_root_mean_squared_error: 0.3133 - y2_output_root_mean_squared_error: 0.4120 - val_loss: 0.9655 - val_y1_output_loss: 0.2176 - val_y2_output_loss: 0.8009 - val_y1_output_root_mean_squared_error: 0.4688 - val_y2_output_root_mean_squared_error: 0.8635
# Epoch 482/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3125 - y1_output_loss: 0.1073 - y2_output_loss: 0.2028 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.4521 - val_loss: 0.6268 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.4497 - val_y1_output_root_mean_squared_error: 0.4302 - val_y2_output_root_mean_squared_error: 0.6646
# Epoch 483/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3163 - y1_output_loss: 0.1056 - y2_output_loss: 0.2127 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4610 - val_loss: 0.9494 - val_y1_output_loss: 0.2239 - val_y2_output_loss: 0.7085 - val_y1_output_root_mean_squared_error: 0.4686 - val_y2_output_root_mean_squared_error: 0.8543
# Epoch 484/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2856 - y1_output_loss: 0.1008 - y2_output_loss: 0.1860 - y1_output_root_mean_squared_error: 0.3164 - y2_output_root_mean_squared_error: 0.4307 - val_loss: 1.2095 - val_y1_output_loss: 0.2916 - val_y2_output_loss: 0.9182 - val_y1_output_root_mean_squared_error: 0.5401 - val_y2_output_root_mean_squared_error: 0.9580
# Epoch 485/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2818 - y1_output_loss: 0.1061 - y2_output_loss: 0.1739 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.4183 - val_loss: 0.6928 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.5224 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.7071
# Epoch 486/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2453 - y1_output_loss: 0.0987 - y2_output_loss: 0.1460 - y1_output_root_mean_squared_error: 0.3146 - y2_output_root_mean_squared_error: 0.3825 - val_loss: 0.7881 - val_y1_output_loss: 0.2232 - val_y2_output_loss: 0.5782 - val_y1_output_root_mean_squared_error: 0.4692 - val_y2_output_root_mean_squared_error: 0.7537
# Epoch 487/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2831 - y1_output_loss: 0.1032 - y2_output_loss: 0.1802 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.4240 - val_loss: 0.8738 - val_y1_output_loss: 0.2632 - val_y2_output_loss: 0.6501 - val_y1_output_root_mean_squared_error: 0.5079 - val_y2_output_root_mean_squared_error: 0.7848
# Epoch 488/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2538 - y1_output_loss: 0.1074 - y2_output_loss: 0.1462 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.3820 - val_loss: 1.2971 - val_y1_output_loss: 0.3071 - val_y2_output_loss: 0.9707 - val_y1_output_root_mean_squared_error: 0.5451 - val_y2_output_root_mean_squared_error: 1.0000
# Epoch 489/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2793 - y1_output_loss: 0.1040 - y2_output_loss: 0.1743 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4189 - val_loss: 0.6683 - val_y1_output_loss: 0.2074 - val_y2_output_loss: 0.4658 - val_y1_output_root_mean_squared_error: 0.4508 - val_y2_output_root_mean_squared_error: 0.6820
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2972 - y1_output_loss: 0.1097 - y2_output_loss: 0.1859 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.4320 - val_loss: 0.6696 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.5017 - val_y1_output_root_mean_squared_error: 0.4330 - val_y2_output_root_mean_squared_error: 0.6944
# Epoch 491/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4083 - y1_output_loss: 0.1302 - y2_output_loss: 0.2757 - y1_output_root_mean_squared_error: 0.3621 - y2_output_root_mean_squared_error: 0.5265 - val_loss: 0.6425 - val_y1_output_loss: 0.1930 - val_y2_output_loss: 0.4670 - val_y1_output_root_mean_squared_error: 0.4337 - val_y2_output_root_mean_squared_error: 0.6741
# Epoch 492/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3010 - y1_output_loss: 0.0989 - y2_output_loss: 0.1997 - y1_output_root_mean_squared_error: 0.3158 - y2_output_root_mean_squared_error: 0.4487 - val_loss: 0.6699 - val_y1_output_loss: 0.1990 - val_y2_output_loss: 0.4806 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.6878
# Epoch 493/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2396 - y1_output_loss: 0.0933 - y2_output_loss: 0.1468 - y1_output_root_mean_squared_error: 0.3032 - y2_output_root_mean_squared_error: 0.3842 - val_loss: 0.7052 - val_y1_output_loss: 0.2126 - val_y2_output_loss: 0.5310 - val_y1_output_root_mean_squared_error: 0.4543 - val_y2_output_root_mean_squared_error: 0.7063
# Epoch 494/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.2489 - y1_output_loss: 0.0888 - y2_output_loss: 0.1595 - y1_output_root_mean_squared_error: 0.2983 - y2_output_root_mean_squared_error: 0.3998 - val_loss: 0.6292 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.4342 - val_y1_output_root_mean_squared_error: 0.4384 - val_y2_output_root_mean_squared_error: 0.6610
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3261 - y1_output_loss: 0.1162 - y2_output_loss: 0.2082 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 0.7389 - val_y1_output_loss: 0.2371 - val_y2_output_loss: 0.5177 - val_y1_output_root_mean_squared_error: 0.4799 - val_y2_output_root_mean_squared_error: 0.7131
# Epoch 496/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2721 - y1_output_loss: 0.0996 - y2_output_loss: 0.1729 - y1_output_root_mean_squared_error: 0.3167 - y2_output_root_mean_squared_error: 0.4145 - val_loss: 0.7306 - val_y1_output_loss: 0.2428 - val_y2_output_loss: 0.4904 - val_y1_output_root_mean_squared_error: 0.4836 - val_y2_output_root_mean_squared_error: 0.7048
# Epoch 497/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2218 - y1_output_loss: 0.0912 - y2_output_loss: 0.1299 - y1_output_root_mean_squared_error: 0.3028 - y2_output_root_mean_squared_error: 0.3607 - val_loss: 0.7464 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.5776 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.7406
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2823 - y1_output_loss: 0.0992 - y2_output_loss: 0.1818 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4281 - val_loss: 0.6677 - val_y1_output_loss: 0.2387 - val_y2_output_loss: 0.4400 - val_y1_output_root_mean_squared_error: 0.4818 - val_y2_output_root_mean_squared_error: 0.6600
# Epoch 499/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3026 - y1_output_loss: 0.1139 - y2_output_loss: 0.1924 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.4359 - val_loss: 1.1735 - val_y1_output_loss: 0.3054 - val_y2_output_loss: 0.8499 - val_y1_output_root_mean_squared_error: 0.5468 - val_y2_output_root_mean_squared_error: 0.9351
# Epoch 500/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3632 - y1_output_loss: 0.1177 - y2_output_loss: 0.2424 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.4944 - val_loss: 0.6623 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.4676 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.6836

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.6623 - y1_output_loss: 0.1951 - y2_output_loss: 0.4572 - y1_output_root_mean_squared_error: 0.4416 - y2_output_root_mean_squared_error: 0.6836
# Loss = 0.6623090497859112, Y1_loss = 0.19509287178516388, Y1_mse = 0.44164150953292847, Y2_loss = 0.45718318223953247, Y2_mse = 0.6835655570030212

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
